# %% [markdown]
# <a href="https://colab.research.google.com/github/SanjayBhargavKudupudi/Dataminning_week2/blob/main/Time_Series_Forecasting_Univariate_with_Exogenous_Variables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-4ad2fa01-e0e8-47f2-a9e6-a6d86460d625" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4ad2fa01-e0e8-47f2-a9e6-a6d86460d625">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !pip install pycaret

# %%
import pandas as pd
import io

data = pd.read_csv(io.BytesIO(uploaded['shopping_time_series_with_dataset.csv']))

# %%
train_data = data.iloc[:-12]  # all data except the last 12 rows
test_data = data.iloc[-12:]   # only the last 12 rows

# %%
from pycaret.time_series import *

# Initialize the setup
s = setup(data=train_data, fold=3, fh=12, session_id=123, numeric_features=["Promotion", "Weekend"], target="Sales", ignore_features=["Date"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-5e399810c21b> in <cell line: 4>()
#       2
#       3 # Initialize the setup
# ----> 4 s = setup(data=train_data, fold=3, fh=12, session_id=123, numeric_features=["Promotion", "Weekend"], target="Sales", ignore_features=["Date"])
#
# TypeError: setup() got an unexpected keyword argument 'numeric_features'
